# %% [markdown]
# ## Red Wine Quality Converted to 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'wine-quality/winequality-red.csv'
features = ['fixed acidity', 'volatile acidity', 'citric acid',
           'residual sugar', 'chlorides', 'free sulfur dioxide',
           'total sulfur dioxide', 'density', 'pH', 'sulphates',
           'alcohol', 'quality']
data = pd.read_csv(path, header=None, names=features, sep=';')
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data[data['quality'] > 6]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 16              8.5             0.280         0.56            1.80      0.092
# 37              8.1             0.380         0.28            2.10      0.066
# 62              7.5             0.520         0.16            1.90      0.085
# 128             8.0             0.590         0.16            1.80      0.065
# 198             5.4             0.835         0.08            1.20      0.046
# 200             9.6             0.320         0.47            1.40      0.056
# 205            12.8             0.300         0.74            2.60      0.095
# 206            12.8             0.300         0.74            2.60      0.095
# 209            11.0             0.300         0.58            2.10      0.054
# ...

# %%
data['quality'].describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
#3,4
#5,6
#7,8
# data.loc[data['quality'] <=4, 'quality'] = 0 
# data.loc[(data['quality'] >4) & (data['quality'] <=6), 'quality'] = 1
# data.loc[(data['quality'] >6), 'quality'] = 2

# %%
data['quality'].describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
x = data.iloc[:, 0:-1].values
y = data.iloc[:, -1].values
# from sklearn.preprocessing import normalize

# x = normalize(x, norm='l2')

from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler()
x, y = ros.fit_sample(x, y)
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.svm import SVC

wine_svc = SVC(kernel='rbf', gamma=500)

# %%
wine_svc.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=500, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
test_predict = wine_svc.predict(X_test)
from sklearn.metrics import accuracy_score
# print(test_predict)
accuracy_score(Y_test, test_predict)
# Out:
# 0.8863080684596577

# %% [markdown]
# ## SVC kernel = rbf

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(wine_svc, x, y, cv=5)
# Out:
# array([0.84671533, 0.84436275, 0.84313725, 0.84558824, 0.87622549])

# %% [markdown]
# ## Random Forest

# %%
from sklearn import ensemble
#设定随机森林分类模型
wine_rf=ensemble.RandomForestClassifier(100) #设定包含100个决策树
from sklearn.model_selection import cross_val_score
score=cross_val_score(wine_rf,x,y,cv=5,scoring='accuracy')

# %%
print(score)
# Out:
# [0.87104623 0.85784314 0.85906863 0.87254902 0.87254902]

# %%
np.mean(score)
# Out:
# 0.8666112065264062
